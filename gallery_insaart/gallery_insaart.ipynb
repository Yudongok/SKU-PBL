# %%
# 모든 타입 힌트가 문자열로 저장되기 때문에, 클래스 정의가 다 끝난 후에 타입 체커가 클래스 안 문자열을 보고 타입을 분석할 수 있다.
# from __future__ import annotations 파이썬 3.11이상부턴 자동으로 지원됨
import os, re, time # re: 정규표현식(문자열 패턴 매칭), time: sleep같은 시간 관련 기능
from dataclasses import dataclass, asdict   # dataclass는 데코레이터이고, asdict은 파이썬 객체를 다른 형식(Json)으로 변환해준다.
# typing모듈은 혼란을 줄이고 안정성과 명확성을 높이기 위해 타입 힌트를 제공한다.
# Optinoal[T]의 경우 T타입일 수도 있고, None일수도 있다.
from typing import Optional, List, Dict, Tuple  
# urllib.parse -> URL문자열을 쪼개고 합치고 인코딩하는 도구들을 모아둔 모듈임
from urllib.parse import urljoin, urlparse, parse_qs, quote

import requests # 통신 라이브러리, HTTP 요청을 매우 쉽게 보낼 수 있게 해주는 라이브러이이다. 특정 URL에 접속하여 HTML소스 코드, 이미지, JSON 데이터 등을 가져온다.
from requests.adapters import HTTPAdapter   # 
from urllib3.util.retry import Retry
from bs4 import BeautifulSoup, NavigableString, Tag, Comment
import pandas as pd
